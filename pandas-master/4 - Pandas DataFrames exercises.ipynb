# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.3.4

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# your code goes here
pd.DataFrame(data = [None],
             index = [None],
             columns = [None])
# Out:
#       NaN
# NaN  None

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
# your code goes here
marvel_df = pd.DataFrame(data = marvel_data)
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add column names to the `marvel_df`

# %%
# your code goes here
col_names = ['name', 'sex', 'first_time_on_TV']
marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first_time_on_TV
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
# your code goes here
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first_time_on_TV
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %%
# your code goes here
marvel_df = marvel_df.drop(['name'], axis = 1)
# marvel_df = marvel_df.drop(columns= ['name'])

marvel_df
# Out:
#                      sex  first_time_on_TV
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
# your code goes here
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis = 0)
marvel_df
# Out:
#                      sex  first_time_on_TV
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
# your code goes here

# marvel_df.head()
# marvel_df.loc['Spider-Man':'Thor',] # index 
# marvel_df.iloc[:5,:] # position
marvel_df.iloc[:5,]
# Out:
#                   sex first_time_on_TV years_since
# name
# Spider-Man       male             1962          60
# Captain America  male             1941          81
# Wolverine        male             1974          48
# Iron Man         male             1963          59
# Thor             male             1963          59

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %%
# your code goes here

# marvel_df.tail()
# marvel_df.loc['Doctor Strange':'Vision',]
marvel_df.iloc[-5:,]
# Out:
#                    sex first_time_on_TV years_since
# name
# Doctor Strange    male             1963          59
# Scarlet Witch   female             1964          58
# Wasp            female             1963          59
# Black Widow     female             1964          58
# Vision            male             1964          58

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
# your code goes here
# marvel_df['sex'].to_frame() # whole the column
# marvel_df.loc['Spider-Man':'Thor',]['sex'].to_frame()

marvel_df.iloc[:5,].sex.to_frame() # the specific column for selected rows
# Out:
#                   sex
# name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
# your code goes here
# marvel_df.iloc[1:-1,]['first_time_on_TV'].to_frame()
marvel_df.iloc[1:-1,].first_time_on_TV.to_frame()
# Out:
#                  first_time_on_TV
# name
# Captain America              1941
# Wolverine                    1974
# Iron Man                     1963
# Thor                         1963
# Thing                        1961
# Mister Fantastic             1961
# Hulk                         1962
# Beast                        1963
# Invisible Woman              1961
# Storm                        1975
# Hawkeye                      1964
# Daredevil                    1964
# Doctor Strange               1963
# Scarlet Witch                1964
# Wasp                         1963
# Black Widow                  1964

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[[0,-1],]
# Out:
#              sex first_time_on_TV years_since
# name
# Spider-Man  male             1962          60
# Vision      male             1964          58

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
# your code goes here
marvel_df.loc['Vision','first_time_on_TV'] = 1964
marvel_df
# Out:
#                      sex first_time_on_TV years_since
# name
# Spider-Man          male             1962          60
# Captain America     male             1941          81
# Wolverine           male             1974          48
# Iron Man            male             1963          59
# Thor                male             1963          59
# Thing               male             1961          61
# Mister Fantastic    male             1961          61
# Hulk                male             1962          60
# Beast               male             1963          59
# Invisible Woman   female             1961          61
# Storm             female             1975          47
# Hawkeye             male             1964          58
# Daredevil           male             1964          58
# Doctor Strange      male             1963          59
# Scarlet Witch     female             1964          58
# Wasp              female             1963          59
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
# your code goes here
marvel_df['years_since'] = 2022 - marvel_df['first_time_on_TV']
marvel_df
# Out:
#                      sex first_time_on_TV years_since
# name
# Spider-Man          male             1962          60
# Captain America     male             1941          81
# Wolverine           male             1974          48
# Iron Man            male             1963          59
# Thor                male             1963          59
# Thing               male             1961          61
# Mister Fantastic    male             1961          61
# Hulk                male             1962          60
# Beast               male             1963          59
# Invisible Woman   female             1961          61
# Storm             female             1975          47
# Hawkeye             male             1964          58
# Daredevil           male             1964          58
# Doctor Strange      male             1963          59
# Scarlet Witch     female             1964          58
# Wasp              female             1963          59
# ...

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
# your code goes here
mask = marvel_df.sex == 'female'
mask
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %%
mask = marvel_df['sex'] == 'female'

mask
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
# your code goes here
mask = marvel_df.sex == 'male'
marvel_df[mask]
# Out:
#                    sex first_time_on_TV years_since
# name
# Spider-Man        male             1962          60
# Captain America   male             1941          81
# Wolverine         male             1974          48
# Iron Man          male             1963          59
# Thor              male             1963          59
# Thing             male             1961          61
# Mister Fantastic  male             1961          61
# Hulk              male             1962          60
# Beast             male             1963          59
# Hawkeye           male             1964          58
# Daredevil         male             1964          58
# Doctor Strange    male             1963          59
# Vision            male             1964          58

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
# your code goes here
mask = marvel_df.first_time_on_TV > 1970
marvel_df[mask]
# Out:
#               sex first_time_on_TV years_since
# name
# Wolverine    male             1974          48
# Storm      female             1975          47

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
# your code goes here
marvel_df[(marvel_df.sex == 'female') & (marvel_df.first_time_on_TV > 1970)]
# Out:
#           sex first_time_on_TV years_since
# name
# Storm  female             1975          47

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
# your code goes here
marvel_df.describe()
marvel_df.first_time_on_TV.mean()
marvel_df['years_since'].max()
# Out:
# 81

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
# your code goes here
marvel_df.first_time_on_TV.mean()
# Out:
# 1962.888888888889

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# your code goes here
marvel_df.first_time_on_TV.min()
# Out:
# 1941

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
# your code goes here
marvel_df[marvel_df.first_time_on_TV == marvel_df.first_time_on_TV.min()]

# or
# mask = marvel_df.first_time_on_TV == marvel_df.first_time_on_TV.min()
# marvel_df[mask]
# Out:
#                   sex first_time_on_TV years_since
# name
# Captain America  male             1941          81

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# your code goes here
marvel_df = marvel_df.reset_index() # the indices go back to numbers from 0sdd

marvel_df
# Out:
#                 name     sex first_time_on_TV years_since
# 0         Spider-Man    male             1962          60
# 1    Captain America    male             1941          81
# 2          Wolverine    male             1974          48
# 3           Iron Man    male             1963          59
# 4               Thor    male             1963          59
# 5              Thing    male             1961          61
# 6   Mister Fantastic    male             1961          61
# 7               Hulk    male             1962          60
# 8              Beast    male             1963          59
# 9    Invisible Woman  female             1961          61
# 10             Storm  female             1975          47
# 11           Hawkeye    male             1964          58
# 12         Daredevil    male             1964          58
# 13    Doctor Strange    male             1963          59
# 14     Scarlet Witch  female             1964          58
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
# your code goes here
marvel_df.first_time_on_TV.plot() # plots vs index
plt.plot(marvel_df.index, marvel_df.first_time_on_TV) # we have to determine X , Y

# %%
#plt.plot(marvel_df.index, marvel_df.first_appearance)
marvel_df.first_appearance.plot()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
# your code goes here
marvel_df.first_time_on_TV.plot.hist()
# plt.hist(marvel_df.first_time_on_TV)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.hist(marvel_df.first_appearance)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
